
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.31291429,  -0.23853013,   1.28985586],
       [ -7.39559951,  -0.23853013,   0.82092419],
       [ -7.47828454,  -0.23853013,   0.3519925 ],
       [ -7.56096956,  -0.23853013,  -0.11693918],
       [ -7.56096956,  -0.23853013,  -0.11693918],
       [ -7.56096956,  -0.23853013,  -0.11693918],
       [ -7.56096956,  -0.23853013,  -0.11693918],
       [ -7.39811138,  -0.23853013,  -0.5643886 ],
       [ -7.2352532 ,  -0.23853013,  -1.01183796],
       [ -7.07239501,  -0.23853013,  -1.45928741],
       [ -6.90953683,  -0.23853013,  -1.90673686],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.74667865,  -0.23853013,  -2.35418632],
       [ -6.66399343,  -0.23853013,  -2.82311808],
       [ -6.58130821,  -0.23853013,  -3.29204984],
       [ -6.49862319,  -0.23853013,  -3.76098161],
       [ -6.41593816,  -0.23853013,  -4.22991337],
       [ -6.33325295,  -0.23853013,  -4.69884513],
       [ -6.33325295,  -0.23853013,  -4.69884513],
       [ -6.17039476,  -0.23853013,  -5.1462944 ],
       [ -6.00753658,  -0.23853013,  -5.59374423],
       [ -5.8446784 ,  -0.23853013,  -6.04119387],
       [ -5.68182021,  -0.23853013,  -6.48864371],
       [ -5.68182021,  -0.23853013,  -6.48864371],
       [ -5.68182021,  -0.23853013,  -6.48864371],
       [ -5.68182021,  -0.23853013,  -6.48864371],
       [ -5.31705598,  -0.23853013,  -6.79471729],
       [ -4.95229174,  -0.23853013,  -7.10079087],
       [ -4.5875275 ,  -0.23853013,  -7.40686426],
       [ -4.5875275 ,  -0.23853013,  -7.40686426],
       [ -4.5875275 ,  -0.23853013,  -7.40686426],
       [ -4.5875275 ,  -0.23853013,  -7.40686426],
       [ -4.11859593,  -0.23853013,  -7.48954947],
       [ -3.64966436,  -0.23853013,  -7.57223469],
       [ -3.18073279,  -0.23853013,  -7.65492029],
       [ -2.71180121,  -0.23853013,  -7.73760589],
       [ -2.71180121,  -0.23853013,  -7.73760589],
       [ -2.71180121,  -0.23853013,  -7.73760589],
       [ -2.29942974,  -0.23853013,  -7.97568872],
       [ -1.88705808,  -0.23853013,  -8.21377156],
       [ -1.47468651,  -0.23853013,  -8.45185439],
       [ -1.06231495,  -0.23853013,  -8.68993723],
       [ -0.64994332,  -0.23853013,  -8.92802007],
       [ -0.23757177,  -0.23853013,  -9.1661029 ],
       [  0.17479979,  -0.23853013,  -9.40418574],
       [  0.58717132,  -0.23853013,  -9.64226857],
       [  0.99954292,  -0.23853013,  -9.88035141],
       [  1.41191445,  -0.23853013, -10.11843424],
       [  1.82428611,  -0.23853013, -10.35651708],
       [  2.23665758,  -0.23853013, -10.59459992],
       [  2.64902925,  -0.23853013, -10.83268275],
       [  3.06140072,  -0.23853013, -11.07076559],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842],
       [  3.47377238,  -0.44365956, -11.30884842]]
       
estimation_points = np.array(estimation_points)
ground_truth = np.array(ground_truth)

# %%
#np.subtract(estimation_points[0],ground_truth[0])
# for adding a new transformation: o3d.visualization.draw_geometries([estimation_pcd, copy.deepcopy(pcd_gt).transform(transformation_matrix_from_angles(t_x=-1.106, t_y=0.04548, t_z=-4.686))])
i = 5
print(np.linalg.norm(np.subtract(ground_truth[i], ground_truth[i+1])))

print(np.linalg.norm(np.subtract(estimation_points[i], estimation_points[i+1])))

np.linalg.norm(np.subtract(estimation_points[i], estimation_points[i+1]))/np.linalg.norm(np.subtract(ground_truth[i], ground_truth[i+1]))
# Out:
# 0.4761657099219415
# 0.4761657038583343
# 0.9999999872657626

# %%
import copy
import scipy.optimize

def clean_coordinates(points, threshold_length=0.46): 
    points = np.array(points)  # convert to a numpy array
    remove_indexes = list()

    for i in range(len(points)):
        if i+1 == len(points):
            break
        
        if np.linalg.norm(np.subtract(points[i], points[i+1])) < threshold_length:  # the length of the vector
            remove_indexes.append(i+1)
    
    if remove_indexes:  # only remove if there is actually something to remove
        points = np.delete(points, np.r_[remove_indexes], axis=0)  # remove the list of indexes along the rows
    
    
    return points  

def transformation_matrix_from_angles(t_x=0, t_y=0, t_z=0, yaw=0, pitch=0, roll=0):

    T = np.vstack((np.hstack((np.identity(3),[[t_x], [t_y], [t_z]])), [0, 0, 0, 1]))  # translation matrix
    #print("T=" + str(T))

    alpha = yaw
    beta = pitch
    gamma = roll
    r_yaw = np.matrix([[np.cos(alpha), -np.sin(alpha), 0], [np.sin(alpha), np.cos(alpha), 0], [0, 0, 1]])
    r_pitch = np.matrix([[np.cos(beta), 0, np.sin(beta)], [0, 1, 0], [-np.sin(beta), 0, np.cos(beta)]])
    r_roll = np.matrix([[1, 0 , 0], [0, np.cos(gamma), -np.sin(gamma)], [0, np.sin(gamma), np.cos(gamma)]])
    rotation_matrix = r_yaw @ r_pitch @ r_roll
    R = np.vstack((np.hstack((rotation_matrix, np.zeros((3,1)))),[0,0,0,1]))  # rotation matrix
    return T@R

def alignment_loss_function(angles, source_point, target_point):
    #global source_point, target_point
    source_point = np.hstack((source_point, [1]))  # append a 1 at the end of the 3D vector since it is a homogeneous coordinate system
    target_point = np.hstack((target_point, [1]))
    yaw, pitch, roll = angles  # unpack the values
    transformation_matrix = transformation_matrix_from_angles(yaw=yaw, pitch=pitch, roll=roll)
    return np.linalg.norm(np.subtract(transformation_matrix@source_point, target_point))  # distance from one vector to the other one MINIMIZE THIS
    

def match_orientation(source_point, target_point):
    sol = scipy.optimize.minimize(alignment_loss_function, x0=[0,0,0], args=(source_point, target_point))
    print(sol)
    return sol
    
ground_truth = clean_coordinates(ground_truth)
estimation_points = clean_coordinates(estimation_points)

t = match_orientation(ground_truth[1], estimation_points[1])
# Out:
#       fun: 4.861424593417565
#  hess_inv: array([[3.65365826, 0.81914813, 1.25686415],
#        [0.81914813, 1.02843333, 0.09520016],
#        [1.25686415, 0.09520016, 1.28286344]])
#       jac: array([ 0.00000000e+00,  1.37090683e-06, -4.76837158e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 84
#       nit: 10
#      njev: 21
#    status: 0
#   success: True
#         x: array([ 2.12521249, -0.3602374 ,  2.80757942])

# %%
t.x[0]
# Out:
# 2.125212490210845
